# %% [markdown]
# # INTERPLANETARY MISSIONS

# %% [markdown]
# ## DATABASE
#
# This database was collected and shared by a Science study manager at ESA/ESTEC
# The prupose of this part is to find a model that can help predicting the cost of an interplanetary mission based on parameters such as mass, instruments,
#
# First, let's take a look at what we have in terms on data for the missions collected.

# %% [markdown]
# - CODE TO 'CLEAN' the NOTEBOOK FOR PRESENTATION

# %%
from IPython.display import HTML
HTML('''<script> 
code_show=true;  
function code_toggle() { 
if (code_show){ 
$('div.input').hide(); 
} else { 
$('div.input').show(); 
} 
code_show = !code_show 
}  
$( document ).ready(code_toggle); 
</script> 
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %% [markdown]
# - IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# - IMPORTING THE DATASET

# %%
ip_missions = pd.read_csv('/Users/ajiacovic/Documents/GitHub/Satellites_Market_study/data/sc_database_planetary.csv', sep=';')

# %%
ip_missions.info()
#This dataset is small but seems to have a few issues: data types(sees commas so things are strings =to_numeric?), missing values,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 66 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   mission                         49 non-null     object
#  1   Agency                          46 non-null     object
#  2   launch dte                      46 non-null     object
#  3   type                            46 non-null     object
#  4   Duration [years]                46 non-null     object
#  5   target                          46 non-null     object
#  6   category                        46 non-null     object
#  7   Instr #                         46 non-null     float64
#  8   Delta V
# km/s                    40 non-null     object
#  9   e.c.                            46 non-null     float64
#  10  Dollar
# /EUR                     46 non-null     object
#  11  Indus Cost
# [MEUR]              37 non-null     object
#  12  Launch
# [MEUR]                  37 non-null     object
#  13  OPS
# [EUR]                      37 non-null     object
#  14  SCI
# [MEUR]                     36 non-null     object
#  15  ESTEC
# [MEUR]                   36 non-null     object
#  16  ESA Cost Risk [MEUR]            36 non-null     object
#  17  CaC at current e.c.             46 non-null     object
#  18  CaC at e.c.
#  [MEUR]             46 non-null     object
#  19  B to FAR                        41 non-null     object
#  20  Maturity of the
# provided info  39 non-null     object
#  21  Comments                        43 non-null     object
#  22  L                               40 non-null     object
#  23  W                               40 non-null     object
#  24  H                               39 non-null     object
#  25  Max drate
#  [kbps]               37 non-null     object
#  26  dMax to Earth                   39 non-null     object
#  27  Antenna [cm]                    37 non-null     object
#  28  Radiators                       37 non-null     object
#  29  SA [kg]                         37 non-null     object
#  30  SA [m2]                         37 non-null     object
#  31  Pmax [W] at max distance        46 non-null     float64
#  32  dMax to Sun                     46 non-null     object
#  33  WET                             46 non-null     object
#  34  DRY Mass                        46 non-null     object
#  35  AOCS                            37 non-null     object
#  36  COMMS                           37 non-null     object
#  37  CPROP                           37 non-null     object
#  38  EPROP                           37 non-null     object
#  39  DHS                             37 non-null     object
#  40  PAYLOAD                         38 non-null     object
#  41  MECH                            37 non-null     object
#  42  POW                             37 non-null     object
#  43  STR                             37 non-null     object
#  44  SYS                             37 non-null     object
#  45  TCS                             37 non-null     object
#  46  HARNESS                         37 non-null     object
#  47  MARGIN                          37 non-null     object
#  48  EPROP.1                         37 non-null     object
#  49  CPROP.1                         37 non-null     object
#  50  RESID                           37 non-null     object
#  51  AOCS.1                          10 non-null     object
#  52  COMMS.1                         10 non-null     object
#  53  CPROP.2                         10 non-null     object
#  54  EPROP.2                         10 non-null     object
#  55  DHS.1                           9 non-null      object
#  56  PAYLOAD.1                       19 non-null     object
#  57  MECH.1                          10 non-null     object
#  58  POW.1                           11 non-null     object
#  59  STR.1                           36 non-null     object
#  60  SYS.1                           14 non-null     object
#  61  TCS.1                           10 non-null     object
#  62  HARNESS.1                       9 non-null      object
#  63  SA kg/m2                        8 non-null      object
#  64  volume                          18 non-null     object
#  65  Density                         17 non-null     object
# dtypes: float64(3), object(63)
# memory usage: 64.1+ KB

# %% [markdown]
# - SOLVING DATA TYPE ISSUES

# %%
ip_missions.head()
# Out:
#           mission    Agency launch dte       type Duration [years]     target  \
# 0             AIM       ESA       2025  planetary                2        NEO
# 1        AKATSUKI      JAXA       2010  planetary              4,5      Venus
# 2    BEPI COLOMBO  ESA/JAXA       2019  planetary                8    Mercury
# 3  CASSINI-HUYENS      NASA       1997  planetary                4     Saturn
# 4            DAWN      NASA          x  planetary                9  Main Belt
#
#          category  Instr # Delta V\nkm/s    e.c.  ... PAYLOAD.1 MECH.1 POW.1  \
# 0             RDV      3.0         1,286  2020.0  ...        5%     0%   10%
# 1         Orbiter      5.0             x  2010.0  ...       NaN    NaN   NaN
# 2  Remote Sensing     11.0             x  2020.0  ...       NaN    NaN   NaN
# 3               x     11.0          2,04  2000.0  ...       NaN    NaN    1%
# 4             RDV      3.0            11  2007.0  ...        6%     2%   28%
#
#   STR.1 SYS.1 TCS.1 HARNESS.1 SA kg/m2    volume      Density
# 0   26%    0%    4%        8%      17%       NaN          NaN
# 1     x   NaN   NaN       NaN      NaN    2,1112  236,8321334
# 2     x   NaN   NaN       NaN      NaN       NaN          NaN
# 3     x   14%   NaN       NaN      NaN     108,8  51,76470588
# 4   15%    0%    6%       11%       0%  3,686556  330,2811621
#
# [5 rows x 66 columns]

# %%
wrong_type_columns = ['Delta V\nkm/s', 'Dollar\n/EUR',
       'Indus Cost \n[MEUR]', 'Launch \n[MEUR]', 'OPS \n[EUR]', 'SCI \n[MEUR]',
       'ESTEC \n[MEUR]', 'ESA Cost Risk [MEUR]', 'CaC at current e.c.',
       'CaC at e.c.\n [MEUR]', 'B to FAR ', 'Maturity of the \nprovided info',
       'Comments ', 'L', 'W', 'H', 'Max drate\n [kbps]', 'dMax to Earth',
       'Antenna [cm]', 'Radiators', 'SA [kg]', 'SA [m2]',
       'dMax to Sun', 'WET', 'DRY Mass', 'AOCS', 'COMMS', 'CPROP', 'EPROP',
       'DHS', 'PAYLOAD', 'MECH', 'POW', 'STR', 'SYS', 'TCS', 'HARNESS',
       'MARGIN', 'EPROP.1', 'CPROP.1', 'RESID', 'AOCS.1', 'COMMS.1', 'CPROP.2',
       'EPROP.2', 'DHS.1', 'PAYLOAD.1', 'MECH.1', 'POW.1', 'STR.1', 'SYS.1',
       'TCS.1', 'HARNESS.1', 'SA kg/m2', 'volume', 'Density','Duration [years]']

# %%
ip_missions[wrong_type_columns] = ip_missions[wrong_type_columns].apply(lambda x: x.str.replace('%', ''), axis=1)
ip_missions[wrong_type_columns]
# Out:
#     Delta V\nkm/s Dollar\n/EUR Indus Cost \n[MEUR] Launch \n[MEUR]  \
# 0           1,286          EUR                 129              75
# 1               x          USD                 NaN             NaN
# 2               x          EUR                   x               x
# 3            2,04          USD                2060             422
# 4              11          USD                 105               0
# ..            ...          ...                 ...             ...
# 119           NaN          NaN                 NaN             NaN
# 120           NaN          NaN                 NaN             NaN
# 121           NaN          NaN                 NaN             NaN
# 122           NaN          NaN                 NaN             NaN
# 123           NaN          NaN                 NaN             NaN
#
#     OPS \n[EUR] SCI \n[MEUR] ESTEC \n[MEUR] ESA Cost Risk [MEUR]  \
# 0          25,1            0           25,9                    0
# 1           NaN          NaN            NaN                  NaN
# 2             x            x              x                    x
# 3           758            x              x                    x
# 4            20            x              x                    x
# ..          ...          ...            ...                  ...
# 119         NaN          NaN            NaN                  NaN
# 120         NaN          NaN            NaN                  NaN
# 121         NaN          NaN            NaN                  NaN
# 122         NaN          NaN            NaN                  NaN
# 123         NaN          NaN            NaN                  NaN
#
#     CaC at current e.c. CaC at e.c.\n [MEUR]  ... MECH.1 POW.1 STR.1 SYS.1  \
# 0                   255                  255  ...      0    10    26     0
# 1           323,1239852                  350  ...    NaN   NaN     x   NaN
# 2                  1650                 1650  ...    NaN   NaN     x   NaN
# 3           3679,860612                 3240  ...    NaN     1     x    14
# 4           435,2789892                  446  ...      2    28    15     0
# ..                  ...                  ...  ...    ...   ...   ...   ...
# 119                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 120                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 121                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 122                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 123                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
#
#     TCS.1 HARNESS.1 SA kg/m2    volume      Density Duration [years]
# 0       4         8       17       NaN          NaN                2
# 1     NaN       NaN      NaN    2,1112  236,8321334              4,5
# 2     NaN       NaN      NaN       NaN          NaN                8
# 3     NaN       NaN      NaN     108,8  51,76470588                4
# 4       6        11        0  3,686556  330,2811621                9
# ..    ...       ...      ...       ...          ...              ...
# 119   NaN       NaN      NaN       NaN          NaN              NaN
# 120   NaN       NaN      NaN       NaN          NaN              NaN
# 121   NaN       NaN      NaN       NaN          NaN              NaN
# 122   NaN       NaN      NaN       NaN          NaN              NaN
# 123   NaN       NaN      NaN       NaN          NaN              NaN
#
# [124 rows x 57 columns]

# %%
ip_missions[wrong_type_columns] = ip_missions[wrong_type_columns].apply(lambda x: x.str.replace(',', '.'), axis=1)
ip_missions[wrong_type_columns]
# Out:
#     Delta V\nkm/s Dollar\n/EUR Indus Cost \n[MEUR] Launch \n[MEUR]  \
# 0           1.286          EUR                 129              75
# 1               x          USD                 NaN             NaN
# 2               x          EUR                   x               x
# 3            2.04          USD                2060             422
# 4              11          USD                 105               0
# ..            ...          ...                 ...             ...
# 119           NaN          NaN                 NaN             NaN
# 120           NaN          NaN                 NaN             NaN
# 121           NaN          NaN                 NaN             NaN
# 122           NaN          NaN                 NaN             NaN
# 123           NaN          NaN                 NaN             NaN
#
#     OPS \n[EUR] SCI \n[MEUR] ESTEC \n[MEUR] ESA Cost Risk [MEUR]  \
# 0          25.1            0           25.9                    0
# 1           NaN          NaN            NaN                  NaN
# 2             x            x              x                    x
# 3           758            x              x                    x
# 4            20            x              x                    x
# ..          ...          ...            ...                  ...
# 119         NaN          NaN            NaN                  NaN
# 120         NaN          NaN            NaN                  NaN
# 121         NaN          NaN            NaN                  NaN
# 122         NaN          NaN            NaN                  NaN
# 123         NaN          NaN            NaN                  NaN
#
#     CaC at current e.c. CaC at e.c.\n [MEUR]  ... MECH.1 POW.1 STR.1 SYS.1  \
# 0                   255                  255  ...      0    10    26     0
# 1           323.1239852                  350  ...    NaN   NaN     x   NaN
# 2                  1650                 1650  ...    NaN   NaN     x   NaN
# 3           3679.860612                 3240  ...    NaN     1     x    14
# 4           435.2789892                  446  ...      2    28    15     0
# ..                  ...                  ...  ...    ...   ...   ...   ...
# 119                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 120                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 121                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 122                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
# 123                 NaN                  NaN  ...    NaN   NaN   NaN   NaN
#
#     TCS.1 HARNESS.1 SA kg/m2    volume      Density Duration [years]
# 0       4         8       17       NaN          NaN                2
# 1     NaN       NaN      NaN    2.1112  236.8321334              4.5
# 2     NaN       NaN      NaN       NaN          NaN                8
# 3     NaN       NaN      NaN     108.8  51.76470588                4
# 4       6        11        0  3.686556  330.2811621                9
# ..    ...       ...      ...       ...          ...              ...
# 119   NaN       NaN      NaN       NaN          NaN              NaN
# 120   NaN       NaN      NaN       NaN          NaN              NaN
# 121   NaN       NaN      NaN       NaN          NaN              NaN
# 122   NaN       NaN      NaN       NaN          NaN              NaN
# 123   NaN       NaN      NaN       NaN          NaN              NaN
#
# [124 rows x 57 columns]

# %%
ip_missions[wrong_type_columns] = ip_missions[wrong_type_columns].apply(pd.to_numeric, errors ='coerce')
ip_missions[wrong_type_columns]
# Out:
#      Delta V\nkm/s  Dollar\n/EUR  Indus Cost \n[MEUR]  Launch \n[MEUR]  \
# 0            1.286           NaN                129.0             75.0
# 1              NaN           NaN                  NaN              NaN
# 2              NaN           NaN                  NaN              NaN
# 3            2.040           NaN               2060.0            422.0
# 4           11.000           NaN                105.0              0.0
# ..             ...           ...                  ...              ...
# 119            NaN           NaN                  NaN              NaN
# 120            NaN           NaN                  NaN              NaN
# 121            NaN           NaN                  NaN              NaN
# 122            NaN           NaN                  NaN              NaN
# 123            NaN           NaN                  NaN              NaN
#
#      OPS \n[EUR]  SCI \n[MEUR]  ESTEC \n[MEUR]  ESA Cost Risk [MEUR]  \
# 0           25.1           0.0            25.9                   0.0
# 1            NaN           NaN             NaN                   NaN
# 2            NaN           NaN             NaN                   NaN
# 3          758.0           NaN             NaN                   NaN
# 4           20.0           NaN             NaN                   NaN
# ..           ...           ...             ...                   ...
# 119          NaN           NaN             NaN                   NaN
# 120          NaN           NaN             NaN                   NaN
# 121          NaN           NaN             NaN                   NaN
# 122          NaN           NaN             NaN                   NaN
# 123          NaN           NaN             NaN                   NaN
#
#      CaC at current e.c.  CaC at e.c.\n [MEUR]  ...  MECH.1  POW.1  STR.1  \
# 0             255.000000                 255.0  ...     0.0   10.0   26.0
# 1             323.123985                 350.0  ...     NaN    NaN    NaN
# 2            1650.000000                1650.0  ...     NaN    NaN    NaN
# 3            3679.860612                3240.0  ...     NaN    1.0    NaN
# 4             435.278989                 446.0  ...     2.0   28.0   15.0
# ..                   ...                   ...  ...     ...    ...    ...
# 119                  NaN                   NaN  ...     NaN    NaN    NaN
# 120                  NaN                   NaN  ...     NaN    NaN    NaN
# 121                  NaN                   NaN  ...     NaN    NaN    NaN
# 122                  NaN                   NaN  ...     NaN    NaN    NaN
# 123                  NaN                   NaN  ...     NaN    NaN    NaN
#
#      SYS.1  TCS.1  HARNESS.1  SA kg/m2      volume     Density  \
# 0      0.0    4.0        8.0      17.0         NaN         NaN
# 1      NaN    NaN        NaN       NaN    2.111200  236.832133
# 2      NaN    NaN        NaN       NaN         NaN         NaN
# 3     14.0    NaN        NaN       NaN  108.800000   51.764706
# 4      0.0    6.0       11.0       0.0    3.686556  330.281162
# ..     ...    ...        ...       ...         ...         ...
# 119    NaN    NaN        NaN       NaN         NaN         NaN
# 120    NaN    NaN        NaN       NaN         NaN         NaN
# 121    NaN    NaN        NaN       NaN         NaN         NaN
# 122    NaN    NaN        NaN       NaN         NaN         NaN
# 123    NaN    NaN        NaN       NaN         NaN         NaN
#
#      Duration [years]
# 0                 2.0
# 1                 4.5
# 2                 8.0
# 3                 4.0
# 4                 9.0
# ..                ...
# 119               NaN
# 120               NaN
# 121               NaN
# 122               NaN
# 123               NaN
#
# [124 rows x 57 columns]

# %%
ip_missions.dtypes
# Out:
# mission              object
# Agency               object
# launch dte           object
# type                 object
# Duration [years]    float64
#                      ...
# TCS.1               float64
# HARNESS.1           float64
# SA kg/m2            float64
# volume              float64
# Density             float64
# Length: 66, dtype: object

# %% [markdown]
# - CLEARING OUT EMPTY ROWS

# %%
#When checking the dataset, I also noticed some 'empty row's' let's check them out:

ip_missions.tail(79)#Ok, it looks as is the dataset was missing the last 78 rows, or that they were added when saved 
#This data comes from excel.
# Out:
#            mission Agency launch dte       type  Duration [years] target  \
# 45   VIKING LANDER   NASA       1975  planetary               4.0   Mars
# 46             NaN    NaN        NaN        NaN               NaN    NaN
# 47             NaN    NaN        NaN        NaN               NaN    NaN
# 48             NaN    NaN        NaN        NaN               NaN    NaN
# 49             NaN    NaN        NaN        NaN               NaN    NaN
# ..             ...    ...        ...        ...               ...    ...
# 119            NaN    NaN        NaN        NaN               NaN    NaN
# 120            NaN    NaN        NaN        NaN               NaN    NaN
# 121          #REF!    NaN        NaN        NaN               NaN    NaN
# 122          #REF!    NaN        NaN        NaN               NaN    NaN
# 123          #REF!    NaN        NaN        NaN               NaN    NaN
#
#     category  Instr #  Delta V\nkm/s    e.c.  ...  PAYLOAD.1  MECH.1  POW.1  \
# 45    Lander      3.0            NaN  2020.0  ...        NaN     NaN    NaN
# 46       NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# 47       NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# 48       NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# 49       NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# ..       ...      ...            ...     ...  ...        ...     ...    ...
# 119      NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# 120      NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# 121      NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# 122      NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
# 123      NaN      NaN            NaN     NaN  ...        NaN     NaN    NaN
#
#      STR.1  SYS.1  TCS.1  HARNESS.1  SA kg/m2  volume  Density
# 45     NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 46     NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 47     NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 48     NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 49     NaN    NaN    NaN        NaN       NaN     NaN      NaN
# ..     ...    ...    ...        ...       ...     ...      ...
# 119    NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 120    NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 121    NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 122    NaN    NaN    NaN        NaN       NaN     NaN      NaN
# 123    NaN    NaN    NaN        NaN       NaN     NaN      NaN
#
# [79 rows x 66 columns]

# %%
ip_missions = ip_missions[:-78]

# %%
ip_missions.dtypes
# Out:
# mission              object
# Agency               object
# launch dte           object
# type                 object
# Duration [years]    float64
#                      ...
# TCS.1               float64
# HARNESS.1           float64
# SA kg/m2            float64
# volume              float64
# Density             float64
# Length: 66, dtype: object

# %% [markdown]
# - CHECKING MISSING VALUES

# %%
missing_values = ip_missions.isnull().sum().sort_values(ascending=False)
missing_values
# Out:
# Dollar\n/EUR                       46
# Comments                           46
# Maturity of the \nprovided info    46
# Radiators                          45
# ESTEC \n[MEUR]                     42
#                                    ..
# CaC at e.c.\n [MEUR]                0
# Pmax [W] at max distance            0
# WET                                 0
# DRY Mass                            0
# mission                             0
# Length: 66, dtype: int64

# %% [markdown]
# - DROPPING EMPTY COLUMNS

# %%
ip_missions.columns
# Out:
# Index(['mission', 'Agency', 'launch dte', 'type', 'Duration [years]', 'target',
#        'category', 'Instr #', 'Delta V\nkm/s', 'e.c.', 'Dollar\n/EUR',
#        'Indus Cost \n[MEUR]', 'Launch \n[MEUR]', 'OPS \n[EUR]', 'SCI \n[MEUR]',
#        'ESTEC \n[MEUR]', 'ESA Cost Risk [MEUR]', 'CaC at current e.c.',
#        'CaC at e.c.\n [MEUR]', 'B to FAR ', 'Maturity of the \nprovided info',
#        'Comments ', 'L', 'W', 'H', 'Max drate\n [kbps]', 'dMax to Earth',
#        'Antenna [cm]', 'Radiators', 'SA [kg]', 'SA [m2]',
#        'Pmax [W] at max distance', 'dMax to Sun', 'WET', 'DRY Mass', 'AOCS',
#        'COMMS', 'CPROP', 'EPROP', 'DHS', 'PAYLOAD', 'MECH', 'POW', 'STR',
#        'SYS', 'TCS', 'HARNESS', 'MARGIN', 'EPROP.1', 'CPROP.1', 'RESID',
#        'AOCS.1', 'COMMS.1', 'CPROP.2', 'EPROP.2', 'DHS.1', 'PAYLOAD.1',
#        'MECH.1', 'POW.1', 'STR.1', 'SYS.1', 'TCS.1', 'HARNESS.1', 'SA kg/m2',
#        'volume', 'Density'],
#       dtype='object')

# %%
ip_missions.drop(['Comments ','Dollar\n/EUR','Maturity of the \nprovided info','e.c.','Radiators'], axis=1, inplace=True)

# %%
#Unfortunately most of the features have too many missing values that cannot be interpolated 
#In the near uture the goal will be to add the information in order to run a more acurate model
#In the meantime, we will drop it, for the purpose of this exercice.

ip_missions.drop(['AOCS', 'COMMS', 'CPROP', 'EPROP',
       'DHS', 'PAYLOAD', 'MECH', 'POW', 'STR', 'SYS', 'TCS', 'HARNESS',
       'MARGIN', 'EPROP.1', 'CPROP.1', 'RESID', 'AOCS.1', 'COMMS.1', 'CPROP.2',
       'EPROP.2', 'DHS.1', 'PAYLOAD.1', 'MECH.1', 'POW.1', 'STR.1', 'SYS.1',
       'TCS.1', 'HARNESS.1','L', 'W', 'H', 'Max drate\n [kbps]', 'dMax to Earth',
       'Antenna [cm]', 'SA [kg]', 'SA [m2]', 'CaC at e.c.\n [MEUR]',
       'B to FAR ', 'Delta V\nkm/s', 'Indus Cost \n[MEUR]',
       'Launch \n[MEUR]', 'OPS \n[EUR]', 'SCI \n[MEUR]', 'ESTEC \n[MEUR]',
       'ESA Cost Risk [MEUR]'],axis =1, inplace=True)

# %%
ip_missions.drop(['SA kg/m2','Density','volume'],axis=1,inplace=True)

# %%
missing_values = ip_missions.isnull().sum().sort_values(ascending=False)
missing_values
# Out:
# DRY Mass                    0
# WET                         0
# dMax to Sun                 0
# Pmax [W] at max distance    0
# CaC at current e.c.         0
# Instr #                     0
# category                    0
# target                      0
# Duration [years]            0
# type                        0
# launch dte                  0
# Agency                      0
# mission                     0
# dtype: int64

# %% [markdown]
# - CHOSING RELEVANT FEATURES / TARGET

# %%
ip_missions.rename(columns={'Duration [years]':'Duration_Years',
                    'launch dte':'Launch_Date','target':'mission_taget',
                    'Instr #':'Instruments','CaC at current e.c.':'Cost',
                    'Pmax [W] at max distance':'Power_Watts','dMax to Sun':'MaxDistance_toSun',
                    'DRY Mass':'Dry_Mass'}, inplace=True)

# %%
ipm_corr = ip_missions.corr()
mask = np.triu(np.ones_like(ipm_corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(ipm_corr,mask=mask, cmap ='Spectral', annot=True)
plt.show()

# %%
ip_missions.category.unique()
#I see many categories here that could be gathered into bigger categories:
# Orbiter - Lander - Flybyer - Probe -Other
# Out:
# array(['RDV', 'Orbiter', 'Remote Sensing', 'x', 'Flybyer',
#        'Sample Return', 'Probe', 'Orbiter ', 'Impactor', 'Lander'],
#       dtype=object)

# %%
ip_missions['Cat'] = ip_missions['category']
ip_m_converter = {'RDV':'Orbiter', 'Remote Sensing':'Orbiter', 'x':'Other',
       'Sample Return':'Other', 'Orbiter ':'Orbiter', 'Impactor':'Other'}
ip_missions['Cat'] = ip_missions['Cat'].replace(ip_m_converter)

# %%
ip_missions.Cat.unique()
# Out:
# array(['Orbiter', 'Other', 'Flybyer', 'Probe', 'Lander'], dtype=object)

# %%
m_cat = ['Orbiter', 'Lander', 'Flybyer', 'Probe','Other']

for cat in m_cat:
    ip_missions[cat] = ip_missions.category.str.contains(cat, regex=False).astype(int)

# %%
ip_missions.drop(['category','Cat'], axis=1,inplace=True)

# %%
ip_missions.drop(['mission', 'Agency', 'Launch_Date', 'type'],axis=1, inplace=True)

# %%
ip_missions['mission_taget'].unique()
# Out:
# array(['NEO', 'Venus', 'Mercury', 'Saturn', 'Main Belt', 'x', 'Europa',
#        'Jupiter', 'Comet', 'Moon', 'Titan', 'Mars', 'Kuiper belt', 'Sun'],
#       dtype=object)

# %%
#These can also be made into categories (that we think can affect the price similarly as a group)
#Small_bodies, Planet, Giant_Planet,
m_target_convert ={'NEO':'Small_bodies', 'Venus':'Planet', 'Mercury':'Planet', 'Saturn':'Giant_Planet', 
                    'Main Belt':'Small_bodies', 'x':'Small_bodies', 'Europa':'Planet',
                    'Jupiter':'Giant_Planet', 'Comet':'Small_bodies', 'Moon':'Planet', 
                    'Titan':'Planet', 'Mars':'Planet', 'Kuiper belt':'Planet', 'Sun':'Planet'}
ip_missions['mission_taget'].replace(m_target_convert, inplace=True)
ip_missions['mission_taget'].unique()
# Out:
# array(['Small_bodies', 'Planet', 'Giant_Planet'], dtype=object)

# %%
m_target = ['Small_bodies', 'Planet', 'Giant_Planet']

for tar in m_target:
    ip_missions[tar] = ip_missions.mission_taget.str.contains(tar, regex=False).astype(int)

# %%
ip_missions.drop('mission_taget', axis=1, inplace=True)

# %%
ip_missions.isnull().sum()
# Out:
# Duration_Years       0
# Instruments          0
# Cost                 0
# Power_Watts          0
# MaxDistance_toSun    0
# WET                  0
# Dry_Mass             0
# Orbiter              0
# Lander               0
# Flybyer              0
# Probe                0
# Other                0
# Small_bodies         0
# Planet               0
# Giant_Planet         0
# dtype: int64

# %%
ip_missions.describe()
# Out:
#        Duration_Years  Instruments         Cost  Power_Watts  \
# count       46.000000    46.000000    46.000000    46.000000
# mean         4.710870     7.521739   773.077441   962.304348
# std          3.293089     3.680212   908.978083   808.849605
# min          0.250000     1.000000    73.626570    32.000000
# 25%          2.000000     5.000000   283.529956   407.000000
# 50%          4.000000     7.000000   407.328085   750.000000
# 75%          7.000000    10.000000   820.360837  1371.250000
# max         12.500000    17.000000  4000.000000  3500.000000
#
#        MaxDistance_toSun          WET     Dry_Mass    Orbiter     Lander  \
# count          46.000000    46.000000    46.000000  46.000000  46.000000
# mean            2.871522  1651.529935   925.399500   0.478261   0.086957
# std             4.669504  1379.525689   717.685456   0.505047   0.284885
# min             0.220000   100.000000   100.000000   0.000000   0.000000
# 25%             1.000000   579.000000   392.210000   0.000000   0.000000
# 50%             1.500000  1127.887500   674.686000   0.000000   0.000000
# 75%             2.652500  2385.500000  1143.825000   1.000000   0.000000
# max            30.000000  5632.000000  3000.000000   1.000000   1.000000
#
#          Flybyer      Probe  Other  Small_bodies     Planet  Giant_Planet
# count  46.000000  46.000000   46.0     46.000000  46.000000     46.000000
# mean    0.152174   0.043478    0.0      0.239130   0.760870      0.130435
# std     0.363158   0.206185    0.0      0.431266   0.431266      0.340503
# min     0.000000   0.000000    0.0      0.000000   0.000000      0.000000
# 25%     0.000000   0.000000    0.0      0.000000   1.000000      0.000000
# 50%     0.000000   0.000000    0.0      0.000000   1.000000      0.000000
# 75%     0.000000   0.000000    0.0      0.000000   1.000000      0.000000
# max     1.000000   1.000000    0.0      1.000000   1.000000      1.000000

# %%
f, ax = plt.subplots(figsize=(12, 8))
ax = sns.boxplot(data=ip_missions,whis=1.5,orient="h",showmeans=True)

#I see a few Outliers here, but :
# for the case of Power: when looking deeper into the data, this mission has a big solar panel, and the power varies with the
#distance to the sun. So, it is normal and should be let in the data. Let's see how the model does

#for the rest, this seems ok

# %%
ip_missions.hist(figsize=(15,12))
#I see here that the data is skewed, and scales are different so we will need to sca;e this!
# Out:
# array([[<AxesSubplot:title={'center':'Duration_Years'}>,
#         <AxesSubplot:title={'center':'Instruments'}>,
#         <AxesSubplot:title={'center':'Cost'}>,
#         <AxesSubplot:title={'center':'Power_Watts'}>],
#        [<AxesSubplot:title={'center':'MaxDistance_toSun'}>,
#         <AxesSubplot:title={'center':'WET'}>,
#         <AxesSubplot:title={'center':'Dry_Mass'}>,
#         <AxesSubplot:title={'center':'Orbiter'}>],
#        [<AxesSubplot:title={'center':'Lander'}>,
#         <AxesSubplot:title={'center':'Flybyer'}>,
#         <AxesSubplot:title={'center':'Probe'}>,
#         <AxesSubplot:title={'center':'Other'}>],
#        [<AxesSubplot:title={'center':'Small_bodies'}>,
#         <AxesSubplot:title={'center':'Planet'}>,
#         <AxesSubplot:title={'center':'Giant_Planet'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
ipm_corr = ip_missions.corr()
mask = np.triu(np.ones_like(ipm_corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(ipm_corr,mask=mask, cmap ='Spectral', annot=True)
plt.show()

#I see the following (stronger) correlations that could be influencing the cost:
# WET : Launch Mass (includes fuel)
# DRY MASS : without the fuel
# DURATION in YEARS 
# INSTRUMENTS : Even if the correlation is not so strong, it will be included, for the sake of this ex.

# %%
sns.set_theme(color_codes=True)

f, axes = plt.subplots(2, 2, figsize=(15, 10))
sns.regplot(x=ip_missions['Dry_Mass'], y=ip_missions['Cost'], color="b",ax=axes[0,0])
sns.regplot(x=ip_missions['WET'], y=ip_missions['Cost'], color="m",ax=axes[0,1])
sns.regplot(x=ip_missions['Duration_Years'], y=ip_missions['Cost'], color="y",ax=axes[1,0])
sns.regplot(x=ip_missions['Instruments'], y=ip_missions['Cost'], color="r",ax=axes[1,1])

#for this model, I chose to do a logistic regression 
#The targuet will be the Cost at completion (CAC) This cost has already been converted to 
#economic conditions based on 2020's given data
#this takes in consideration, the infaltion variance
# Out:
# <AxesSubplot:xlabel='Instruments', ylabel='Cost'>

# %% [markdown]
# - SCALING THE FEATURES

# %%
ip_missions.columns
# Out:
# Index(['Duration_Years', 'Instruments', 'Cost', 'Power_Watts',
#        'MaxDistance_toSun', 'WET', 'Dry_Mass', 'Orbiter', 'Lander', 'Flybyer',
#        'Probe', 'Other', 'Small_bodies', 'Planet', 'Giant_Planet'],
#       dtype='object')

# %%
#THIS IS A WAY TO SCALE BUT IT WOULD BE BETTER TO APPLY SPECIFIC SCALING

# from sklearn.preprocessing import RobustScaler

# y = ip_missions['Cost']
# X = ip_missions.drop('Cost', axis=1)

# Robust_Scaler = RobustScaler()

# scaled_X = Robust_Scaler.fit_transform(X)

# %%
#SPECIFIC SCALING:
#Astronomical unit
#Logaritmic scaling for dryMass

# %% [markdown]
# - SPLITTING THE DATA (TRAIN/TEST)

# %%
from sklearn.model_selection import train_test_split

y = ip_missions['Cost']
X = ip_missions.drop('Cost', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20,random_state=42)

# %% [markdown]
# - IMPORTING AND CHOSING THE MODEL TO APPLY
# (Linear Reg, SVM, RandomForest)

# %%
from sklearn.ensemble import RandomForestRegressor

score_train=[]
score_test=[]
for i in range(2,12,2):
    model = RandomForestRegressor(max_depth=i).fit(X_train, y_train)
    #max depth cannot be 0
    score_train.append(model.score(X_train,y_train))
    score_test.append(model.score(X_test,y_test))
    print(f'for max_depth: {i}\nthe train scores are:\n {score_train}\nThe test scores are:\n {score_test}')
# Out:
# for max_depth: 2
# the train scores are:
#  [0.6952579894456915]
# The test scores are:
#  [0.5589004812300946]
# for max_depth: 4
# the train scores are:
#  [0.6952579894456915, 0.812990864080682]
# The test scores are:
#  [0.5589004812300946, 0.5489161669430209]
# for max_depth: 6
# the train scores are:
#  [0.6952579894456915, 0.812990864080682, 0.8343162460440099]
# The test scores are:
#  [0.5589004812300946, 0.5489161669430209, 0.573917316853737]
# for max_depth: 8
# the train scores are:
#  [0.6952579894456915, 0.812990864080682, 0.8343162460440099, 0.7862288795715378]
# The test scores are:
#  [0.5589004812300946, 0.5489161669430209, 0.573917316853737, 0.594643893013135]
# for max_depth: 10
# the train scores are:
#  [0.6952579894456915, 0.812990864080682, 0.8343162460440099, 0.7862288795715378, 0.8571125593941837]
# The test scores are:
#  [0.5589004812300946, 0.5489161669430209, 0.573917316853737, 0.594643893013135, 0.6231889787497145]

# %% [markdown]
# - CHECKING ACCURACY/PLOTTING

# %%
from sklearn.metrics import mean_squared_error
y_pred=model.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 376090.4862447486
